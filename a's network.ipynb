# %%
import networkx as nximport csvimport jsonimport matplotlib.pyplot as plt

# %%
output = []

# %%
g = nx.Graph()

# %%
with open("/home/yods/work/nesta-data/addy.csv", 'rb') as csvfile:    r = csv.reader(csvfile, delimiter=',')    for row in r:        output.append(row)

# %%
output[0]
# Out:
# ['danielknell', 'addyosmani']

# %%
a = [g.add_edges_from([(row)]) for row in output]

# %%
nx.draw(g)plt.show()

# %%
output2 = []

# %%
with open("/home/yods/work/nesta-data/addyresp.csv", 'rb') as csvfile:    r = csv.reader(csvfile, delimiter=',')    for row in r:        output2.append(row)
