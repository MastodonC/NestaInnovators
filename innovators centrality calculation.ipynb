# %%
import networkx as nximport csvimport jsonimport matplotlib.pyplot as plt

# %%
output = []

# %%
g = nx.DiGraph()

# %%
with open("/home/yods/work/innovators/data-processing/output/innovators-following/part-00000", 'rb') as csvfile:    r = csv.reader(csvfile, delimiter=',')    for row in r:        output.append(row)

# %%
output[0]
# Out:
# ['9point6', 'jennyj4']

# %%
a = [g.add_edges_from([(row)]) for row in output]

# %%
g.nodes()
# Out:
# ['pietromalerba', 'kazkazAMQ', 'pparidans', 'helxsz', 'bacanapps', 'andfinally', 'fredrikmollerstrand', 'arboleya', 'katieadams', 'meslater', 'dokital', 'Jackio90', 'aulvi', 'lazerwalker', 'iamtimm', 'richthegeek', 'cjbloc', 'bredele', 'adamdougal', 'hcilab', 'meryn', 'fent', 'simonfan', 'gduverger', 'ahmetabdi', 'alexbiz', 'kitcambridge', 'jhulick', 'FLemon', 'helrond', 'marcol', 'evanlh', 'iqbalperkasa', 'Davidslv', 'pacopa', 'syoichi', 'jpstroop', 'rkatic', 'willmot', 'ozzzy', 'robmiller', 'kankod', 'lantiga', 'saas786', 'crazed', 'Kainne', 'Epic720', 'danielmoore', 'jbilcke', 'Raynos', 'duhaime', 'orourkedesign', 'ChristianGaertner', 'lildude', 'andrearufo', 'oykun', 'repoman', 'tklun', 'IAmFledge', 'mtaarao', 'afinzel', 'michaelBenin', 'chrisrowe', 'wsh', 'jgwhite', 'carolgann', 'ktstowell', 'asmega', 'Shmee007', 'anthonygeranio', 'gdimoff', 'zhenyong', 'JT5D', 'wookiehangover', 'jden', 'digitalicarus', 'angineering', 'finalfantasia', 'fabriziogiordano', 'volpino', 'abhisekp', '
# ...

# %%
degree = nx.degree_centrality(g)

# %%
degree
# Out:
# {'0wls': 0.0008764241893076249, '1stvamp': 0.0008764241893076249, '3rd-Eden': 0.0008764241893076249, '46bit': 0.0008764241893076249, '9point6': 0.006134969325153374, 'AbhiAgarwal': 0.0008764241893076249, 'AgtLucas': 0.0008764241893076249, 'AhmadAbd-Elghany': 0.0008764241893076249, 'AndreasMadsen': 0.0008764241893076249, 'AndrewHenderson': 0.0008764241893076249, 'ArtemTitoulenko': 0.0008764241893076249, 'Asysob': 0.0008764241893076249, 'AvianFlu': 0.0008764241893076249, 'AzizLight': 0.0008764241893076249, 'Bartinger': 0.0008764241893076249, 'BennettJames': 0.0008764241893076249, 'Benvie': 0.0008764241893076249, 'Beornwulf': 0.0008764241893076249, 'BlaneCordes': 0.0008764241893076249, 'BradleyJennings': 0.0008764241893076249, 'BrettBukowski': 0.0008764241893076249, 'BronsonQuick': 0.0008764241893076249, 'Calamitous': 0.0008764241893076249, 'CatmanIX': 0.0008764241893076249, 'ChadSki': 0.0008764241893076249, 'ChrisWren': 0.0008764241893076249, 'ChristianGaertner': 0.0008764241893076249,
# ...

# %%
closeness = nx.closeness_centrality(g)

# %%
closeness
# Out:
# {'0wls': 0.0, '1stvamp': 0.0, '3rd-Eden': 0.0, '46bit': 0.0, '9point6': 0.006134969325153374, 'AbhiAgarwal': 0.0, 'AgtLucas': 0.0, 'AhmadAbd-Elghany': 0.0, 'AndreasMadsen': 0.0, 'AndrewHenderson': 0.0, 'ArtemTitoulenko': 0.0, 'Asysob': 0.0, 'AvianFlu': 0.0, 'AzizLight': 0.0, 'Bartinger': 0.0, 'BennettJames': 0.0, 'Benvie': 0.0, 'Beornwulf': 0.0, 'BlaneCordes': 0.0, 'BradleyJennings': 0.0, 'BrettBukowski': 0.0, 'BronsonQuick': 0.0, 'Calamitous': 0.0, 'CatmanIX': 0.0, 'ChadSki': 0.0, 'ChrisWren': 0.0, 'ChristianGaertner': 0.0, 'Constellation': 0.0, 'D4v1X': 0.0, 'DMClambo': 0.0, 'DavidBruant': 0.0, 'Davidslv': 0.0, 'DexterLB': 0.0, 'DorkScript': 0.0, 'DrMurx': 0.0, 'DrPep': 0.0, 'Epic720': 0.0, 'FLemon': 0.007887817703768623, 'FeipingHunag': 0.0, 'Ferrari': 0.0, 'Flave': 0.0, 'Flawe': 0.0035056967572304996, 'ForbesLindesay': 0.0, 'Fortnox': 0.0, 'Garfield-fr': 0.0, 'GeeBar': 0.0, 'Geekfish': 0.0, 'Gerst20051': 0.0, 'GiantKiwi': 0.006134969325153374, 'GregBrant': 0.0, 'GuidoS': 0.0, 'HH
# ...

# %%
nx.draw(g)plt.show()
